# %%
import os
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot([1,2,3],[4,5,6])

# %%
np.arange(5)
# Out:
# array([0, 1, 2, 3, 4])

# %%
plt.plot(np.arange(5),np.arange(5))
